# %% [markdown]
# # Informatievisualisatie - Individuele opdracht
#
# |Groepsleden|
# ---
# |Qi Draaisma |
# |Eva Oostenbrink|
# |Sam Tegel |
# |Thomas Wiggers|

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go

# Start notebook mode
init_notebook_mode(connected=True)

import pandas as pd 
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding = "ISO-8859-1")


print(" ".join(df.keys()))

df.head(n=10) # eerste 10 van de in totaal 17 rijen

set(df["weaptype1_txt"])
# Out:
# C:\Users\Eva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
#Qi en Sam 1

# %%
#Qi en Sam 2

# %%
#Qi en Sam 3

# %%
#Qi en Sam 4

# %%
#Qi en Sam 5

# %%
#Qi en Sam 6
years = list(set(df['iyear']))

df_budget = pd.read_csv('military-expenditure-as-share-of-gdp.csv',  encoding = "ISO-8859-1")
us_budget = df_budget[df_budget['Code'] == 'USA']
us_budget = us_budget[us_budget['Year'] > 1970]


world_budget = [np.average(df_budget[df_budget['Year'] == year]['Expenditure']) for year in years]
df_budget.head(n=10)


# Create a trace
budget_trace = go.Scatter(
    x = us_budget['Year'],
    y = world_budget,
    yaxis='y2',
    name="Global spending"
)


deaths_per_year = [np.nansum(df[df['iyear'] == year]['nkill']) for year in years]


data = go.Bar(
    name="Deaths",
    x=years,
    y=deaths_per_year
)

layout = go.Layout(
    title='Number of deaths by terrorist attacks per year',
    yaxis=dict(
        title='Number of deaths'
    ),
    yaxis2=dict(
        title='World budget as percent of gpb',
        overlaying='y',
        side='right'
    )
)



fig = go.Figure(data=[data, budget_trace], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="90e34cd7-fdbb-4990-89ff-9bfb1934555f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("90e34cd7-fdbb-4990-89ff-9bfb1934555f")) {
#                     Plotly.newPlot(
#                         '90e34cd7-fdbb-4990-89ff-9bfb1934555f',
# ...

# %%
#Qi en Sam extra

# %%
#Thomas histogram
data = go.Histogram(
    x=df['iyear']
)

layout = go.Layout(
    title='Number of attacks per year'
)

fig = go.Figure(data=[data], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="6a7c3816-248f-46c1-aeeb-1be885143a26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6a7c3816-248f-46c1-aeeb-1be885143a26")) {
#                     Plotly.newPlot(
#                         '6a7c3816-248f-46c1-aeeb-1be885143a26',
# ...

# %%
#Thomas Donut chart


kills_per_country = df.groupby("country_txt").sum()

number_of_counties = 9
top = kills_per_country.sort_values('nkill',ascending=0).head(number_of_counties)
bottom = np.sum(kills_per_country.sort_values('nkill',ascending=0)[number_of_counties:]["nkill"])
print(bottom)




# countries = set(df["country_txt"])

# kills_per_country = {country:np.sum(df[df["country_txt"] == country]["nkill"]) for country in countries}


# countries = df.sort_values('nkill').head(10)["country_txt"]
# # countries

labels = list(top.index.get_level_values(0))
values = list(top["nkill"])

labels.append("rest")
values.append(bottom)


sliders = [dict(
    active = 10,
    currentvalue = {"prefix": "Frequency: "},
    pad = {"t": 50},
#     steps = steps
)]

layout = dict(sliders=sliders)

trace = go.Pie(labels=labels, values=values, hole=0.5, textinfo='label')

iplot([trace])
# Out:
# 169822.0
# <div>
#
#
#             <div id="e431438d-0f26-4de5-82f1-b8cd653abbdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e431438d-0f26-4de5-82f1-b8cd653abbdd")) {
#                     Plotly.newPlot(
#                         'e431438d-0f26-4de5-82f1-b8cd653abbdd',
#                         [{"hole": 0.5, "labels": ["Iraq", "Afghanistan", "Pakistan", "Nigeria", "India", "Sri Lanka", "Syria", "Colombia", "Peru", "rest"], "textinfo": "label", "type": "pie", "uid": "c7f39ee4-e270-494f-b684-73fea0515422", "values": [78589.0, 39384.0, 23822.0, 22682.0, 19341.0, 15530.0, 15229.0, 14698.0, 12771.0, 169822.0]}],
#                         {},
# ...

# %%
#Thomas Bubble chart
df_pop = pd.read_csv('country_population.csv', encoding = "ISO-8859-1")
df_pop.head(10)

junk_size = 4 # skip anything that isnt the year columns
pop = df_pop[df_pop["Country Name"] == "World"].values.tolist()[0][junk_size:]
years = list(df_pop)[junk_size:]


kpcs = kills_per_country.sort_values('nkill',ascending=1)

trace_pop = go.Scatter(
    x = kpcs.index,
    y = kpcs["nkill"],
    name="Global population",
    mode='markers',
    marker=dict(
        size=kpcs["nkill"]/1000,
    )
)





iplot([trace_pop])
# kills_per_country

#1970 - 2017
# Out:
# <div>
#
#
#             <div id="3f44d0c7-aaa2-4bca-b648-a62d6d66805e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f44d0c7-aaa2-4bca-b648-a62d6d66805e")) {
#                     Plotly.newPlot(
#                         '3f44d0c7-aaa2-4bca-b648-a62d6d66805e',
# ...

# %%
#Thomas World map

#kills per country
kpc = df.groupby("country_txt").sum()

#get country names
countries = kpc.index.get_level_values(0)
#country lattitude and longitude
cll = df.groupby("country_txt").median()


scl = [0,"rgb(150,0,90)"],[0.125,"rgb(0, 0, 200)"],[0.25,"rgb(0, 25, 255)"],\
[0.375,"rgb(0, 152, 255)"],[0.5,"rgb(44, 255, 150)"],[0.625,"rgb(151, 255, 0)"],\
[0.75,"rgb(255, 234, 0)"],[0.875,"rgb(255, 111, 0)"],[1,"rgb(255, 0, 0)"]

data = [go.Scattergeo(
    lat = cll["latitude"],
    lon = cll["longitude"],
    text = kpc['nkill'].astype(str) + " deaths in " + countries.astype(str),
    marker = dict(
        color = kpc['nkill'],
        colorscale = scl,
        reversescale = False,
        opacity = 0.7,
        size = np.log(kpc['nkill'], where=kpc['nkill']>0)*4,        
        colorbar = dict(
            thickness = 10,
            titleside = "right",
            outlinecolor = "rgba(68, 68, 68, 0)",
            ticks = "outside",
            ticksuffix = " deaths",
        )                
    )
)]

layout = dict(
    geo = dict(
        scope = 'world',
        showland = True,
        landcolor = "rgb(212, 212, 212)",
        subunitcolor = "rgb(255, 255, 255)",
        countrycolor = "rgb(255, 255, 255)",
        showlakes = True,
        lakecolor = "rgb(255, 255, 255)",
        showsubunits = True,
        showcountries = True,
        resolution = 50,
        projection = dict(
            type = 'conic conformal',
            rotation = dict(
                lon = -100
            )
        ),
        lonaxis = dict(
            showgrid = True,
            gridwidth = 0.5,
            range= [ -140.0, -55.0 ],
            dtick = 5
        ),
        lataxis = dict (
            showgrid = True,
            gridwidth = 0.5,
            range= [ 20.0, 60.0 ],
            dtick = 5
        )
    ),
    title = 'Attacks resulting in more than 5 deaths',
)

fig = go.Figure(data=data, layout=layout )
iplot(fig)
# Out:
# <div>
#
#
#             <div id="e17bcd58-b30d-45dc-bc92-2929f4298a79" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e17bcd58-b30d-45dc-bc92-2929f4298a79")) {
#                     Plotly.newPlot(
#                         'e17bcd58-b30d-45dc-bc92-2929f4298a79',
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [
    [0.0, 'rgb(242,240,247)'],
    [0.2, 'rgb(218,218,235)'],
    [0.4, 'rgb(188,189,220)'],
    [0.6, 'rgb(158,154,200)'],
    [0.8, 'rgb(117,107,177)'],
    [1.0, 'rgb(84,39,143)']
]

df['text'] = df['state'] + '<br>' + \
    'Beef ' + df['beef'] + ' Dairy ' + df['dairy'] + '<br>' + \
    'Fruits ' + df['total fruits'] + ' Veggies ' + df['total veggies'] + '<br>' + \
    'Wheat ' + df['wheat'] + ' Corn ' + df['corn']

data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = df['code'],
    z = df['total exports'].astype(float),
    locationmode = 'USA-states',
    text = df['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Millions USD")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = '2011 US Agriculture Exports by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'world',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# <div>
#
#
#             <div id="cf4fb755-a1c7-45ad-9600-e4b266b774b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cf4fb755-a1c7-45ad-9600-e4b266b774b4")) {
#                     Plotly.newPlot(
#                         'cf4fb755-a1c7-45ad-9600-e4b266b774b4',
# ...

# %%
#Thomas Extra

kills = df.groupby("weaptype1_txt").sum()["nwound"]
attacks = df.groupby("weaptype1_txt").count()["eventid"]
print(len(kills), len(attacks))
kpa = kills/attacks

weapons = kills.index


trace = go.Pie(labels=weapons, values=kpa, hole=0.5, textinfo='label', showlegend=False)

iplot([trace])


effect = df.groupby("weaptype1_txt")[["nwound","nkill"]].sum()

effect["nattacks"] = df.groupby("weaptype1_txt").count()["eventid"]
effect["kpa"] = kpa
effect


# traces = []
# for w in effect.index:
#     trace = go.Scatter(
#         x = effect,
#         y = kpcs["nkill"],
#         name=w,
#     )
#     traces.append(trace)
    
years = list(range(1970, 2018))
deaths_per_year = [np.nansum(df[df['iyear'] == year]['nkill']) for year in years]
inj_per_year = [np.nansum(df[df['iyear'] == year]['nwound']) for year in years]


effect = [d/i for i,d in zip(inj_per_year,deaths_per_year) if i is not 0]

death = go.Scatter(
    name="Effect",
    x=years,
    y=effect
)

# inj = go.Scatter(
#     name="Injured",
#     x=years,
#     y=inj_per_year,
# )

layout = go.Layout(
    title='Intensity of attacks (deaths per injured)',
    yaxis=dict(
        title='Number of deaths'
    ),
)



fig = go.Figure(data=[death], layout=layout)
iplot(fig)
    


# import squarify

# x = 0.
# y = 0.
# width = 100.
# height = 100.

# values = kpa

# normed = squarify.normalize_sizes(values, width, height)
# rects = squarify.squarify(normed, x, y, width, height)

# # Choose colors from http://colorbrewer2.org/ under "Export"
# color_brewer = ['rgb(166,206,227)','rgb(31,120,180)','rgb(178,223,138)',
#                 'rgb(51,160,44)','rgb(251,154,153)','rgb(227,26,28)']
# shapes = []
# annotations = []
# counter = 0

# for r in rects:
#     shapes.append( 
#         dict(
#             type = 'rect', 
#             x0 = r['x'], 
#             y0 = r['y'], 
#             x1 = r['x']+r['dx'], 
#             y1 = r['y']+r['dy'],
#             line = dict( width = 2 ),
#             fillcolor = color_brewer[counter]
#         ) 
#     )
#     annotations.append(
#         dict(
#             x = r['x']+(r['dx']/2),
#             y = r['y']+(r['dy']/2),
#             text = values[counter],
#             showarrow = False
#         )
#     )
#     counter = counter + 1
#     if counter >= len(color_brewer):
#         counter = 0

# # For hover text
# trace0 = go.Scatter(
#     x = [ r['x']+(r['dx']/2) for r in rects ], 
#     y = [ r['y']+(r['dy']/2) for r in rects ],
#     text = weapons, 
#     mode = 'text',
# )
        
# layout = dict(
#     height=700, 
#     width=700,
#     xaxis=dict(showgrid=False,zeroline=False),
#     yaxis=dict(showgrid=False,zeroline=False),
#     shapes=shapes,
#     annotations=annotations,
#     hovermode='closest'
# )

# # With hovertext
# figure = dict(data=[trace0], layout=layout)

# # Without hovertext
# # figure = dict(data=[Scatter()], layout=layout)

# iplot(figure)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b74ad5c182ae> in <module>()
#       1 #Thomas Extra
#       2
# ----> 3 kills = df.groupby("weaptype1_txt").sum()["nwound"]
#       4 attacks = df.groupby("weaptype1_txt").count()["eventid"]
#       5 print(len(kills), len(attacks))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
# ...

# %%
years = list(range(1970, 2018))
deaths_per_year = [np.nansum(df[df['iyear'] == year]['nkillus']) for year in years]



death = go.Scatter(
    name="Kills us",
    x=years,
    y=deaths_per_year
)


layout = go.Layout(
    title='Us deaths',
    yaxis=dict(
        title='Number of deaths'
    ),
)



fig = go.Figure(data=[death], layout=layout)
iplot(fig)

# %%
weapon= df[df["weaptype1_txt"] == 'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'].groupby("iyear").agg('count')["eventid"]
allevents = df.groupby("iyear").count()
allevents = allevents["eventid"]

weapon = weapon.loc['2010':'2017']
allevents = allevents.loc['2010':'2017']

trace = go.Scatter(
    x = weapon.index,
    y = weapon.pct_change(),
    name = "groei vehicle attacks"
)

trace2 = go.Scatter(
    x = weapon.index,
    y = allevents.pct_change(),
    name = "groei attacks"
)

layout = go.Layout(
    title=go.layout.Title(
        text='Groei (vehicle) attacks',
    )
)

data = [trace, trace2]

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weaptype1_txt'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-1fbadb683d31> in <module>()
# ...

# %%
#Eva 2

# %%
# Eva 3

# %%
#Eva extra
